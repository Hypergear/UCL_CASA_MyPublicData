# %% [markdown]
# # This python notebook illustrate some code were used in CASA0013 course work 2

# %%
import pandas as pd

xxxx = pd.read_csv("https://github.com/Hypergear/UCL_CASA_MyPublicData/blob/main/Fsds/CW3/2020-08-24-listings.csv.gz?raw=true")
# Out:
# /opt/homebrew/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (2,22,36,41,45,46,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        id     listing_url scrape_id last_scraped name  \
# 3559  NaN             NaN       NaN          NaN    f
# 29990 NaN  within an hour      100%          74%    f
#
#                                              description  \
# 3559   https://a0.muscache.com/im/pictures/user/1c171...
# 29990  https://a0.muscache.com/im/pictures/user/19315...
#
#                                    neighborhood_overview picture_url  host_id  \
# 3559   https://a0.muscache.com/im/pictures/user/1c171...  Shoreditch      1.0
# 29990  https://a0.muscache.com/im/pictures/user/19315...    Richmond      1.0
#
#       host_url  ... review_scores_communication review_scores_location  \
# ...

# %%
xxxx[xxxx['id'].isna()]
# Out:
#        id     listing_url scrape_id last_scraped name  \
# 3559  NaN             NaN       NaN          NaN    f
# 29990 NaN  within an hour      100%          74%    f
#
#                                              description  \
# 3559   https://a0.muscache.com/im/pictures/user/1c171...
# 29990  https://a0.muscache.com/im/pictures/user/19315...
#
#                                    neighborhood_overview picture_url  host_id  \
# 3559   https://a0.muscache.com/im/pictures/user/1c171...  Shoreditch      1.0
# 29990  https://a0.muscache.com/im/pictures/user/19315...    Richmond      1.0
#
#       host_url  ... review_scores_communication review_scores_location  \
# 3559       1.0  ...                         NaN                    NaN
# 29990      1.0  ...                         NaN                    NaN
#
#       review_scores_value license instant_bookable  \
# 3559                  NaN     NaN              NaN
# 29990                 NaN     NaN              NaN
#
# ...
